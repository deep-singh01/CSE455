# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cse455/assignments/assignment4/'
FOLDERNAME = 'cse455/assignments/assignment4_colab/assignment4/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the COCO dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cse455/datasets/
# !bash get_dataset.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/content/drive/My Drive/cse455/assignments/assignment4_colab/assignment4//cse455/datasets/'
# /content/drive/My Drive/cse455/assignments/assignment4_colab/assignment4
# --2025-02-25 01:38:35--  http://vision.stanford.edu/teaching/cs131_fall1718/files/data/hw6/faces.tar.gz
# Resolving vision.stanford.edu (vision.stanford.edu)... 171.64.68.10
# Connecting to vision.stanford.edu (vision.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2257223 (2.2M) [application/x-gzip]
# Saving to: ‘faces.tar.gz.1’
#
# faces.tar.gz.1      100%[===================>]   2.15M   983KB/s    in 2.2s
#
# 2025-02-25 01:38:38 (983 KB/s) - ‘faces.tar.gz.1’ saved [2257223/2257223]
#
# faces/train/johnny depp/39.jpg
# faces/train/leonardo dicaprio/19.jpg
# faces/train/natalie portman/12.jpg
# faces/train/tom cruise/48.jpg
# faces/train/leonardo dicaprio/
# faces/train/leonardo dicaprio/36.jpg
# faces/train/johnny depp/56.jpg
# faces/train/angelina jolie/10.jpg
# faces/train/scarlett johansson/48.jpg
# faces/train/scarlett johansson/5.jpg
# faces/train/hillary clinton/22.jpg
# faces/test/justin timberlake/13.jpg
# faces/train/brad pitt/25.jpg
# faces/train/angelina jolie/29.jpg
# faces/test/emma watson/2.jpg
# faces/test/angelina jolie/11.jpg
# faces/train/justin timberlake/19.jpg
# faces/train/anne hathaway/27.jpg
# faces/train/brad pitt/42.jpg
# faces/train/angelina jolie/46.jpg
# faces/train/jennifer aniston/43.jpg
# faces/train/cristiano ronaldo/15.jpg
# faces/train/hillary clinton/58.jpg
# faces/test/brad pitt/6.jpg
# faces/train/barack obama/11.jpg
# faces/train/justin timberlake/36.jpg
# faces/train/angelina jolie/2.jpg
# faces/train/anne hathaway/44.jpg
# faces/train/jennifer aniston/60.jpg
# faces/train/cristiano ronaldo/32.jpg
# faces/test/anne hathaway/13.jpg
# faces/train/george clooney/6.jpg
# faces/test/emma watson/
# faces/train/emma watson/26.jpg
# faces/train/justin timberlake/53.jpg
# faces/train/johnny depp/
# faces/train/george clooney/20.jpg
# faces/test/cristiano ronaldo/7.jpg
# faces/train/barack obama/47.jpg
# faces/test/angelina jolie/7.jpg
# faces/test/leonardo dicaprio/6.jpg
# faces/train/emma watson/43.jpg
# faces/train/george clooney/39.jpg
# faces/test/tom cruise/8.jpg
# faces/train/anne hathaway/6.jpg
# faces/train/johnny depp/28.jpg
# faces/train/tom cruise/37.jpg
# faces/train/tom cruise/4.jpg
# faces/train/nicole kidman/24.jpg
# faces/train/cristiano ronaldo/5.jpg
# faces/test/scarlett johansson/7.jpg
# faces/train/hillary clinton/1.jpg
# faces/train/johnny depp/45.jpg
# faces/train/leonardo dicaprio/25.jpg
# faces/train/leonardo dicaprio/4.jpg
# faces/train/scarlett johansson/37.jpg
# faces/test/johnny depp/11.jpg
# faces/train/hillary clinton/11.jpg
# faces/train/nicole kidman/41.jpg
# faces/train/brad pitt/14.jpg
# faces/train/angelina jolie/18.jpg
# faces/test/nicole kidman/10.jpg
# faces/train/angelina jolie/35.jpg
# faces/train/leonardo dicaprio/42.jpg
# faces/train/anne hathaway/16.jpg
# faces/train/
# faces/train/brad pitt/31.jpg
# faces/test/scarlett johansson/13.jpg
# faces/train/jennifer aniston/32.jpg
# faces/train/hillary clinton/47.jpg
# faces/train/natalie portman/30.jpg
# faces/train/justin timberlake/25.jpg
# faces/train/anne hathaway/33.jpg
# faces/train/nicole kidman/53.jpg
# faces/train/cristiano ronaldo/21.jpg
# faces/train/barack obama/19.jpg
# faces/train/natalie portman/49.jpg
# faces/test/johnny depp/4.jpg
# faces/train/emma watson/15.jpg
# faces/train/justin timberlake/42.jpg
# faces/train/anne hathaway/50.jpg
# faces/test/jennifer aniston/11.jpg
# faces/train/barack obama/3.jpg
# faces/test/george clooney/10.jpg
# faces/test/jennifer aniston/8.jpg
# faces/train/emma watson/32.jpg
# faces/train/george clooney/28.jpg
# faces/train/brad pitt/4.jpg
# faces/train/justin timberlake/2.jpg
# faces/train/johnny depp/17.jpg
# faces/train/barack obama/53.jpg
# faces/train/tom cruise/26.jpg
# faces/train/george clooney/45.jpg
# faces/train/nicole kidman/13.jpg
# faces/test/tom cruise/13.jpg
# faces/train/johnny depp/34.jpg
# faces/train/leonardo dicaprio/14.jpg
# faces/train/scarlett johansson/26.jpg
# faces/train/tom cruise/43.jpg
# faces/train/nicole kidman/30.jpg
# faces/test/barack obama/5.jpg
# faces/test/anne hathaway/1.jpg
# faces/train/hillary clinton/9.jpg
# faces/train/natalie portman/26.jpg
# faces/train/johnny depp/51.jpg
# faces/train/leonardo dicaprio/31.jpg
# faces/train/hillary clinton/19.jpg
# faces/train/scarlett johansson/43.jpg
# faces/train/brad pitt/20.jpg
# faces/train/angelina jolie/24.jpg
# faces/train/jennifer aniston/21.jpg
# faces/train/brad pitt/56.jpg
# faces/train/hillary clinton/36.jpg
# faces/train/brad pitt/39.jpg
# faces/train/justin timberlake/14.jpg
# faces/train/anne hathaway/22.jpg
# faces/train/emma watson/5.jpg
# faces/train/justin timberlake/
# faces/train/cristiano ronaldo/10.jpg
# faces/train/johnny depp/6.jpg
# faces/train/jennifer aniston/6.jpg
# faces/train/natalie portman/38.jpg
# faces/train/hillary clinton/53.jpg
# faces/test/brad pitt/1.jpg
# faces/train/cristiano ronaldo/29.jpg
# faces/train/natalie portman/7.jpg
# faces/train/justin timberlake/31.jpg
# faces/train/barack obama/25.jpg
# faces/train/natalie portman/55.jpg
# faces/train/george clooney/1.jpg
# faces/train/cristiano ronaldo/46.jpg
# faces/train/emma watson/21.jpg
# faces/train/george clooney/17.jpg
# faces/test/barack obama/14.jpg
# faces/test/cristiano ronaldo/2.jpg
# faces/test/leonardo dicaprio/1.jpg
# faces/train/tom cruise/15.jpg
# faces/test/tom cruise/3.jpg
# faces/train/george clooney/34.jpg
# faces/test/angelina jolie/2.jpg
# faces/train/anne hathaway/1.jpg
# faces/train/johnny depp/23.jpg
# faces/test/hillary clinton/4.jpg
# faces/train/scarlett johansson/15.jpg
# faces/train/tom cruise/32.jpg
# faces/test/george clooney/6.jpg
# faces/train/natalie portman/15.jpg
# faces/train/nicole kidman/38.jpg
# faces/test/scarlett johansson/2.jpg
# faces/train/johnny depp/40.jpg
# faces/train/leonardo dicaprio/20.jpg
# faces/train/scarlett johansson/32.jpg
# faces/train/angelina jolie/13.jpg
# faces/train/nicole kidman/5.jpg
# faces/train/johnny depp/59.jpg
# faces/train/jennifer aniston/10.jpg
# faces/train/leonardo dicaprio/39.jpg
# faces/train/scarlett johansson/8.jpg
# faces/train/brad pitt/28.jpg
# faces/train/anne hathaway/11.jpg
# faces/train/jennifer aniston/29.jpg
# faces/test/justin timberlake/
# faces/test/justin timberlake/6.jpg
# faces/test/emma watson/5.jpg
# faces/train/leonardo dicaprio/56.jpg
# faces/train/hillary clinton/42.jpg
# faces/train/brad pitt/45.jpg
# faces/train/jennifer aniston/46.jpg
# faces/train/cristiano ronaldo/18.jpg
# faces/train/justin timberlake/20.jpg
# faces/test/brad pitt/9.jpg
# faces/train/barack obama/14.jpg
# faces/train/natalie portman/44.jpg
# faces/train/angelina jolie/5.jpg
# faces/train/justin timberlake/39.jpg
# faces/train/anne hathaway/47.jpg
# faces/train/cristiano ronaldo/35.jpg
# faces/train/emma watson/10.jpg
# faces/train/george clooney/9.jpg
# faces/train/justin timberlake/56.jpg
# faces/train/emma watson/29.jpg
# faces/test/jennifer aniston/3.jpg
# faces/train/george clooney/23.jpg
# faces/train/johnny depp/12.jpg
# faces/train/emma watson/46.jpg
# faces/train/tom cruise/21.jpg
# faces/train/george clooney/40.jpg
# faces/train/anne hathaway/9.jpg
# faces/train/tom cruise/7.jpg
# faces/train/nicole kidman/27.jpg
# faces/train/scarlett johansson/21.jpg
# faces/train/cristiano ronaldo/8.jpg
# faces/train/brad pitt/17.jpg
# faces/train/hillary clinton/4.jpg
# faces/train/johnny depp/48.jpg
# faces/train/leonardo dicaprio/28.jpg
# faces/train/leonardo dicaprio/7.jpg
# faces/test/barack obama/
# faces/train/hillary clinton/14.jpg
# faces/train/nicole kidman/44.jpg
# faces/train/jennifer aniston/18.jpg
# faces/train/leonardo dicaprio/45.jpg
# faces/train/hillary clinton/31.jpg
# faces/train/brad pitt/34.jpg
# faces/train/jennifer aniston/35.jpg
# faces/train/angelina jolie/38.jpg
# faces/train/angelina jolie/55.jpg
# faces/train/johnny depp/1.jpg
# faces/train/jennifer aniston/1.jpg
# faces/train/natalie portman/33.jpg
# faces/train/nicole kidman/56.jpg
# faces/train/justin timberlake/28.jpg
# faces/train/anne hathaway/36.jpg
# faces/train/brad pitt/51.jpg
# faces/train/natalie portman/2.jpg
# faces/train/jennifer aniston/52.jpg
# faces/train/cristiano ronaldo/24.jpg
# faces/train/barack obama/20.jpg
# faces/train/natalie portman/50.jpg
# faces/train/justin timberlake/45.jpg
# faces/train/emma watson/18.jpg
# faces/train/anne hathaway/53.jpg
# faces/train/george clooney/12.jpg
# faces/train/cristiano ronaldo/41.jpg
# faces/train/barack obama/39.jpg
# faces/train/barack obama/6.jpg
# faces/train/emma watson/35.jpg
# faces/train/tom cruise/10.jpg
# faces/train/brad pitt/7.jpg
# faces/test/george clooney/13.jpg
# faces/train/barack obama/56.jpg
# faces/test/leonardo dicaprio/11.jpg
# faces/train/tom cruise/29.jpg
# faces/train/george clooney/48.jpg
# faces/train/nicole kidman/16.jpg
# faces/train/scarlett johansson/10.jpg
# faces/test/
# faces/train/leonardo dicaprio/17.jpg
# faces/train/scarlett johansson/29.jpg
# faces/train/tom cruise/46.jpg
# faces/train/nicole kidman/33.jpg
# faces/train/natalie portman/29.jpg
# faces/train/johnny depp/54.jpg
# faces/train/scarlett johansson/3.jpg
# faces/train/scarlett johansson/46.jpg
# faces/train/hillary clinton/20.jpg
# faces/test/justin timberlake/11.jpg
# faces/train/jennifer aniston/24.jpg
# faces/train/angelina jolie/27.jpg
# faces/test/justin timberlake/1.jpg
# faces/train/leonardo dicaprio/51.jpg
# faces/test/nicole kidman/8.jpg
# faces/train/justin timberlake/17.jpg
# faces/train/anne hathaway/25.jpg
# faces/train/cristiano ronaldo/13.jpg
# faces/train/angelina jolie/44.jpg
# faces/train/jennifer aniston/41.jpg
# faces/train/emma watson/8.jpg
# faces/train/jennifer aniston/9.jpg
# faces/test/hillary clinton/11.jpg
# faces/test/brad pitt/4.jpg
# faces/train/hillary clinton/56.jpg
# faces/train/brad pitt/59.jpg
# faces/train/justin timberlake/34.jpg
# faces/train/anne hathaway/42.jpg
# faces/train/cristiano ronaldo/30.jpg
# faces/test/anne hathaway/11.jpg
# faces/train/barack obama/28.jpg
# faces/train/george clooney/4.jpg
# faces/train/cristiano ronaldo/49.jpg
# faces/train/emma watson/24.jpg
# faces/train/justin timberlake/51.jpg
# faces/test/cristiano ronaldo/5.jpg
# faces/train/barack obama/45.jpg
# faces/train/tom cruise/18.jpg
# faces/train/george clooney/37.jpg
# faces/train/emma watson/41.jpg
# faces/test/leonardo dicaprio/4.jpg
# faces/test/tom cruise/6.jpg
# faces/train/anne hathaway/4.jpg
# faces/train/johnny depp/26.jpg
# faces/test/george clooney/9.jpg
# faces/train/scarlett johansson/18.jpg
# faces/test/hillary clinton/7.jpg
# faces/train/tom cruise/35.jpg
# faces/train/tom cruise/2.jpg
# faces/train/nicole kidman/22.jpg
# faces/train/cristiano ronaldo/3.jpg
# faces/train/natalie portman/18.jpg
# faces/test/scarlett johansson/5.jpg
# faces/train/leonardo dicaprio/2.jpg
# faces/train/scarlett johansson/35.jpg
# faces/train/nicole kidman/8.jpg
# faces/train/angelina jolie/16.jpg
# faces/train/hillary clinton/28.jpg
# faces/test/justin timberlake/9.jpg
# faces/train/anne hathaway/14.jpg
# faces/train/angelina jolie/33.jpg
# faces/train/jennifer aniston/30.jpg
# faces/train/leonardo dicaprio/59.jpg
# faces/train/hillary clinton/45.jpg
# faces/train/jennifer aniston/49.jpg
# faces/train/justin timberlake/23.jpg
# faces/train/anne hathaway/31.jpg
# faces/train/angelina jolie/50.jpg
# faces/train/nicole kidman/51.jpg
# faces/train/barack obama/17.jpg
# faces/train/natalie portman/47.jpg
# faces/train/angelina jolie/8.jpg
# faces/test/johnny depp/2.jpg
# faces/train/cristiano ronaldo/38.jpg
# faces/train/emma watson/13.jpg
# faces/train/justin timberlake/40.jpg
# faces/train/barack obama/34.jpg
# faces/train/george clooney/26.jpg
# faces/train/barack obama/1.jpg
# faces/train/emma watson/30.jpg
# faces/train/brad pitt/2.jpg
# faces/train/johnny depp/15.jpg
# faces/train/barack obama/51.jpg
# faces/train/emma watson/49.jpg
# faces/train/tom cruise/24.jpg
# faces/test/emma watson/15.jpg
# faces/train/george clooney/43.jpg
# faces/train/nicole kidman/11.jpg
# faces/test/tom cruise/11.jpg
# faces/train/johnny depp/32.jpg
# faces/train/leonardo dicaprio/12.jpg
# faces/train/scarlett johansson/24.jpg
# faces/train/tom cruise/41.jpg
# faces/test/barack obama/3.jpg
# faces/train/hillary clinton/7.jpg
# faces/train/natalie portman/24.jpg
# faces/train/hillary clinton/17.jpg
# faces/train/nicole kidman/47.jpg
# faces/train/scarlett johansson/41.jpg
# faces/train/angelina jolie/22.jpg
# faces/train/brad pitt/54.jpg
# faces/train/hillary clinton/34.jpg
# faces/train/brad pitt/37.jpg
# faces/test/natalie portman/15.jpg
# faces/test/nicole kidman/3.jpg
# faces/train/jennifer aniston/38.jpg
# faces/train/justin timberlake/12.jpg
# faces/train/anne hathaway/20.jpg
# faces/train/johnny depp/4.jpg
# faces/train/jennifer aniston/55.jpg
# faces/train/emma watson/3.jpg
# faces/train/jennifer aniston/4.jpg
# faces/train/natalie portman/36.jpg
# faces/train/hillary clinton/51.jpg
# faces/train/anne hathaway/39.jpg
# faces/train/angelina jolie/58.jpg
# faces/train/natalie portman/5.jpg
# faces/train/cristiano ronaldo/27.jpg
# faces/train/barack obama/23.jpg
# faces/train/natalie portman/53.jpg
# faces/train/justin timberlake/48.jpg
# faces/test/natalie portman/6.jpg
# faces/train/george clooney/15.jpg
# faces/train/cristiano ronaldo/44.jpg
# faces/test/barack obama/12.jpg
# faces/train/emma watson/38.jpg
# faces/train/barack obama/9.jpg
# faces/train/tom cruise/13.jpg
# faces/train/justin timberlake/8.jpg
# faces/train/george clooney/32.jpg
# faces/train/barack obama/59.jpg
# faces/test/leonardo dicaprio/14.jpg
# faces/train/tom cruise/30.jpg
# faces/train/johnny depp/21.jpg
# faces/train/scarlett johansson/13.jpg
# faces/train/nicole kidman/19.jpg
# faces/test/hillary clinton/2.jpg
# faces/test/george clooney/4.jpg
# faces/train/natalie portman/13.jpg
# faces/train/nicole kidman/36.jpg
# faces/train/tom cruise/49.jpg
# faces/train/scarlett johansson/30.jpg
# faces/test/anne hathaway/7.jpg
# faces/train/scarlett johansson/49.jpg
# faces/train/nicole kidman/3.jpg
# faces/train/johnny depp/57.jpg
# faces/train/angelina jolie/11.jpg
# faces/train/leonardo dicaprio/37.jpg
# faces/train/scarlett johansson/6.jpg
# faces/train/natalie portman/
# faces/train/hillary clinton/23.jpg
# faces/train/brad pitt/26.jpg
# faces/train/jennifer aniston/27.jpg
# faces/test/cristiano ronaldo/10.jpg
# faces/test/justin timberlake/4.jpg
# faces/test/emma watson/3.jpg
# faces/train/leonardo dicaprio/54.jpg
# faces/train/brad pitt/43.jpg
# faces/train/hillary clinton/40.jpg
# faces/train/anne hathaway/28.jpg
# faces/train/cristiano ronaldo/16.jpg
# faces/train/jennifer aniston/44.jpg
# faces/train/angelina jolie/47.jpg
# faces/train/jennifer aniston/
# faces/train/hillary clinton/59.jpg
# faces/train/barack obama/12.jpg
# faces/test/brad pitt/7.jpg
# faces/train/angelina jolie/3.jpg
# faces/train/natalie portman/42.jpg
# faces/train/justin timberlake/37.jpg
# faces/train/anne hathaway/45.jpg
# faces/train/brad pitt/60.jpg
# faces/train/cristiano ronaldo/33.jpg
# faces/test/anne hathaway/14.jpg
# faces/train/george clooney/7.jpg
# faces/train/emma watson/27.jpg
# faces/train/justin timberlake/54.jpg
# faces/test/jennifer aniston/1.jpg
# faces/train/george clooney/21.jpg
# faces/train/cristiano ronaldo/50.jpg
# faces/test/cristiano ronaldo/8.jpg
# faces/train/barack obama/48.jpg
# faces/test/tom cruise/9.jpg
# faces/train/johnny depp/10.jpg
# faces/test/angelina jolie/8.jpg
# faces/train/emma watson/44.jpg
# faces/test/leonardo dicaprio/7.jpg
# faces/test/emma watson/10.jpg
# faces/train/anne hathaway/7.jpg
# faces/train/johnny depp/29.jpg
# faces/train/tom cruise/38.jpg
# faces/train/tom cruise/5.jpg
# faces/train/nicole kidman/25.jpg
# faces/train/cristiano ronaldo/6.jpg
# faces/train/scarlett johansson/38.jpg
# faces/train/hillary clinton/2.jpg
# faces/train/johnny depp/46.jpg
# faces/train/leonardo dicaprio/26.jpg
# faces/train/leonardo dicaprio/5.jpg
# faces/test/johnny depp/12.jpg
# faces/train/brad pitt/15.jpg
# faces/train/hillary clinton/12.jpg
# faces/train/nicole kidman/42.jpg
# faces/train/angelina jolie/19.jpg
# faces/train/jennifer aniston/16.jpg
# faces/test/nicole kidman/11.jpg
# faces/train/leonardo dicaprio/43.jpg
# faces/train/jennifer aniston/33.jpg
# faces/train/anne hathaway/17.jpg
# faces/test/natalie portman/10.jpg
# faces/train/angelina jolie/36.jpg
# faces/test/scarlett johansson/14.jpg
# faces/train/natalie portman/31.jpg
# faces/train/angelina jolie/53.jpg
# faces/train/justin timberlake/26.jpg
# faces/train/anne hathaway/34.jpg
# faces/train/nicole kidman/54.jpg
# faces/train/jennifer aniston/50.jpg
# faces/train/cristiano ronaldo/22.jpg
# faces/test/johnny depp/5.jpg
# faces/train/emma watson/16.jpg
# faces/train/justin timberlake/43.jpg
# faces/train/anne hathaway/51.jpg
# faces/test/natalie portman/1.jpg
# faces/train/george clooney/10.jpg
# faces/test/jennifer aniston/12.jpg
# faces/train/barack obama/37.jpg
# faces/train/george clooney/29.jpg
# faces/test/jennifer aniston/9.jpg
# faces/train/barack obama/4.jpg
# faces/train/emma watson/33.jpg
# faces/train/brad pitt/5.jpg
# faces/train/justin timberlake/3.jpg
# faces/train/johnny depp/18.jpg
# faces/train/tom cruise/27.jpg
# faces/train/george clooney/46.jpg
# faces/train/nicole kidman/14.jpg
# faces/train/emma watson/50.jpg
# faces/test/tom cruise/14.jpg
# faces/train/scarlett johansson/27.jpg
# faces/train/leonardo dicaprio/15.jpg
# faces/train/scarlett johansson/1.jpg
# faces/train/tom cruise/44.jpg
# faces/test/anne hathaway/2.jpg
# faces/train/nicole kidman/31.jpg
# faces/train/natalie portman/27.jpg
# faces/train/johnny depp/52.jpg
# faces/test/brad pitt/
# faces/train/leonardo dicaprio/32.jpg
# faces/train/scarlett johansson/44.jpg
# faces/train/cristiano ronaldo/
# faces/train/brad pitt/21.jpg
# faces/train/jennifer aniston/22.jpg
# faces/train/angelina jolie/25.jpg
# faces/train/hillary clinton/37.jpg
# faces/train/justin timberlake/15.jpg
# faces/train/anne hathaway/23.jpg
# faces/train/cristiano ronaldo/11.jpg
# faces/train/angelina jolie/42.jpg
# faces/train/johnny depp/7.jpg
# faces/train/emma watson/6.jpg
# faces/train/jennifer aniston/7.jpg
# faces/test/brad pitt/2.jpg
# faces/train/hillary clinton/54.jpg
# faces/train/brad pitt/57.jpg
# faces/train/natalie portman/8.jpg
# faces/train/jennifer aniston/58.jpg
# faces/train/anne hathaway/40.jpg
# faces/test/tom cruise/
# faces/train/barack obama/26.jpg
# faces/train/natalie portman/56.jpg
# faces/train/george clooney/2.jpg
# faces/test/natalie portman/9.jpg
# faces/train/george clooney/18.jpg
# faces/train/cristiano ronaldo/47.jpg
# faces/train/emma watson/22.jpg
# faces/test/cristiano ronaldo/3.jpg
# faces/train/barack obama/43.jpg
# faces/train/tom cruise/16.jpg
# faces/train/george clooney/35.jpg
# faces/test/angelina jolie/3.jpg
# faces/test/leonardo dicaprio/2.jpg
# faces/train/anne hathaway/2.jpg
# faces/train/johnny depp/24.jpg
# faces/train/barack obama/60.jpg
# faces/test/george clooney/7.jpg
# faces/train/scarlett johansson/16.jpg
# faces/test/hillary clinton/5.jpg
# faces/train/tom cruise/33.jpg
# faces/train/nicole kidman/20.jpg
# faces/train/cristiano ronaldo/1.jpg
# faces/train/johnny depp/41.jpg
# faces/train/leonardo dicaprio/21.jpg
# faces/train/nicole kidman/39.jpg
# faces/train/scarlett johansson/33.jpg
# faces/test/cristiano ronaldo/
# faces/train/jennifer aniston/11.jpg
# faces/train/brad pitt/10.jpg
# faces/train/tom cruise/
# faces/train/nicole kidman/6.jpg
# faces/train/angelina jolie/14.jpg
# faces/train/scarlett johansson/9.jpg
# faces/train/hillary clinton/26.jpg
# faces/train/brad pitt/29.jpg
# faces/train/scarlett johansson/50.jpg
# faces/test/emma watson/6.jpg
# faces/test/justin timberlake/7.jpg
# faces/train/anne hathaway/12.jpg
# faces/test/angelina jolie/15.jpg
# faces/train/angelina jolie/31.jpg
# faces/train/leonardo dicaprio/57.jpg
# faces/train/justin timberlake/21.jpg
# faces/train/hillary clinton/43.jpg
# faces/train/brad pitt/46.jpg
# faces/train/nicole kidman/
# faces/train/jennifer aniston/47.jpg
# faces/train/cristiano ronaldo/19.jpg
# faces/
# faces/train/natalie portman/45.jpg
# faces/train/hillary clinton/60.jpg
# faces/train/angelina jolie/6.jpg
# faces/train/anne hathaway/48.jpg
# faces/train/cristiano ronaldo/36.jpg
# faces/train/emma watson/11.jpg
# faces/train/barack obama/32.jpg
# faces/train/justin timberlake/57.jpg
# faces/test/jennifer aniston/4.jpg
# faces/train/george clooney/24.jpg
# faces/train/johnny depp/13.jpg
# faces/train/emma watson/47.jpg
# faces/train/tom cruise/22.jpg
# faces/train/george clooney/41.jpg
# faces/train/scarlett johansson/
# faces/train/tom cruise/8.jpg
# faces/train/johnny depp/30.jpg
# faces/train/leonardo dicaprio/10.jpg
# faces/train/nicole kidman/28.jpg
# faces/train/scarlett johansson/22.jpg
# faces/train/cristiano ronaldo/9.jpg
# faces/train/brad pitt/
# faces/train/hillary clinton/5.jpg
# faces/train/johnny depp/49.jpg
# faces/train/leonardo dicaprio/8.jpg
# faces/train/nicole kidman/45.jpg
# faces/train/angelina jolie/20.jpg
# faces/train/leonardo dicaprio/46.jpg
# faces/test/angelina jolie/
# faces/train/angelina jolie/39.jpg
# faces/train/hillary clinton/32.jpg
# faces/train/brad pitt/35.jpg
# faces/test/natalie portman/13.jpg
# faces/test/nicole kidman/1.jpg
# faces/train/jennifer aniston/36.jpg
# faces/train/justin timberlake/10.jpg
# faces/train/johnny depp/2.jpg
# faces/train/jennifer aniston/53.jpg
# faces/train/emma watson/1.jpg
# faces/train/jennifer aniston/2.jpg
# faces/train/emma watson/
# faces/train/angelina jolie/56.jpg
# faces/train/justin timberlake/29.jpg
# faces/train/anne hathaway/37.jpg
# faces/train/nicole kidman/57.jpg
# faces/train/natalie portman/3.jpg
# faces/train/cristiano ronaldo/25.jpg
# faces/test/johnny depp/8.jpg
# faces/train/barack obama/21.jpg
# faces/train/natalie portman/51.jpg
# faces/train/emma watson/19.jpg
# faces/train/justin timberlake/46.jpg
# faces/train/george clooney/13.jpg
# faces/train/cristiano ronaldo/42.jpg
# faces/test/jennifer aniston/15.jpg
# faces/test/barack obama/10.jpg
# faces/train/barack obama/7.jpg
# faces/train/emma watson/36.jpg
# faces/train/tom cruise/11.jpg
# faces/train/brad pitt/8.jpg
# faces/test/george clooney/14.jpg
# faces/train/george clooney/30.jpg
# faces/train/barack obama/57.jpg
# faces/train/george clooney/49.jpg
# faces/train/scarlett johansson/11.jpg
# faces/test/george clooney/2.jpg
# faces/train/nicole kidman/34.jpg
# faces/train/natalie portman/11.jpg
# faces/train/leonardo dicaprio/18.jpg
# faces/train/tom cruise/47.jpg
# faces/test/barack obama/9.jpg
# faces/test/anne hathaway/5.jpg
# faces/train/nicole kidman/1.jpg
# faces/train/johnny depp/55.jpg
# faces/train/scarlett johansson/47.jpg
# faces/train/scarlett johansson/4.jpg
# faces/train/brad pitt/24.jpg
# faces/train/angelina jolie/28.jpg
# faces/train/jennifer aniston/25.jpg
# faces/test/justin timberlake/2.jpg
# faces/test/angelina jolie/10.jpg
# faces/test/emma watson/1.jpg
# faces/train/leonardo dicaprio/52.jpg
# faces/test/nicole kidman/9.jpg
# faces/train/justin timberlake/18.jpg
# faces/train/anne hathaway/26.jpg
# faces/train/emma watson/9.jpg
# faces/train/angelina jolie/45.jpg
# faces/train/cristiano ronaldo/14.jpg
# faces/test/hillary clinton/12.jpg
# faces/train/hillary clinton/57.jpg
# faces/test/brad pitt/5.jpg
# faces/train/barack obama/10.jpg
# faces/train/natalie portman/40.jpg
# faces/train/justin timberlake/35.jpg
# faces/train/anne hathaway/43.jpg
# faces/train/george clooney/
# faces/train/cristiano ronaldo/31.jpg
# faces/train/barack obama/29.jpg
# faces/test/anne hathaway/12.jpg
# faces/train/natalie portman/59.jpg
# faces/train/george clooney/5.jpg
# faces/train/emma watson/25.jpg
# faces/test/cristiano ronaldo/6.jpg
# faces/train/tom cruise/19.jpg
# faces/train/george clooney/38.jpg
# faces/train/emma watson/42.jpg
# faces/test/tom cruise/7.jpg
# faces/train/anne hathaway/5.jpg
# faces/train/johnny depp/27.jpg
# faces/train/tom cruise/3.jpg
# faces/train/scarlett johansson/19.jpg
# faces/train/tom cruise/36.jpg
# faces/train/nicole kidman/23.jpg
# faces/train/leonardo dicaprio/3.jpg
# faces/train/cristiano ronaldo/4.jpg
# faces/train/natalie portman/19.jpg
# faces/test/scarlett johansson/6.jpg
# faces/train/johnny depp/44.jpg
# faces/train/leonardo dicaprio/24.jpg
# faces/train/scarlett johansson/36.jpg
# faces/train/angelina jolie/17.jpg
# faces/train/hillary clinton/10.jpg
# faces/train/brad pitt/13.jpg
# faces/train/nicole kidman/9.jpg
# faces/train/jennifer aniston/14.jpg
# faces/train/leonardo dicaprio/41.jpg
# faces/train/hillary clinton/29.jpg
# faces/test/scarlett johansson/12.jpg
# faces/train/brad pitt/30.jpg
# faces/test/emma watson/9.jpg
# faces/train/jennifer aniston/31.jpg
# faces/train/angelina jolie/34.jpg
# faces/train/hillary clinton/46.jpg
# faces/train/brad pitt/49.jpg
# faces/train/anne hathaway/32.jpg
# faces/train/nicole kidman/52.jpg
# faces/train/cristiano ronaldo/20.jpg
# faces/train/barack obama/18.jpg
# faces/train/natalie portman/48.jpg
# faces/train/angelina jolie/9.jpg
# faces/test/johnny depp/3.jpg
# faces/train/cristiano ronaldo/39.jpg
# faces/train/emma watson/14.jpg
# faces/train/justin timberlake/41.jpg
# faces/test/jennifer aniston/10.jpg
# faces/train/george clooney/27.jpg
# faces/train/barack obama/2.jpg
# faces/train/emma watson/31.jpg
# faces/train/brad pitt/3.jpg
# faces/train/justin timberlake/1.jpg
# faces/train/johnny depp/16.jpg
# faces/train/barack obama/52.jpg
# faces/train/tom cruise/25.jpg
# faces/train/george clooney/44.jpg
# faces/train/nicole kidman/12.jpg
# faces/test/tom cruise/12.jpg
# faces/train/angelina jolie/
# faces/train/johnny depp/33.jpg
# faces/train/leonardo dicaprio/13.jpg
# faces/train/scarlett johansson/25.jpg
# faces/train/tom cruise/42.jpg
# faces/test/barack obama/4.jpg
# faces/train/barack obama/
# faces/train/natalie portman/25.jpg
# faces/train/leonardo dicaprio/30.jpg
# faces/train/johnny depp/50.jpg
# faces/train/hillary clinton/18.jpg
# faces/train/nicole kidman/48.jpg
# faces/train/scarlett johansson/42.jpg
# faces/test/leonardo dicaprio/
# faces/train/jennifer aniston/20.jpg
# faces/train/angelina jolie/23.jpg
# faces/train/leonardo dicaprio/49.jpg
# faces/train/hillary clinton/35.jpg
# faces/train/brad pitt/38.jpg
# faces/test/nicole kidman/4.jpg
# faces/train/jennifer aniston/39.jpg
# faces/train/justin timberlake/13.jpg
# faces/train/anne hathaway/21.jpg
# faces/train/angelina jolie/40.jpg
# faces/train/johnny depp/5.jpg
# faces/train/emma watson/4.jpg
# faces/train/natalie portman/37.jpg
# faces/train/brad pitt/55.jpg
# faces/train/justin timberlake/30.jpg
# faces/train/natalie portman/6.jpg
# faces/train/jennifer aniston/56.jpg
# faces/train/cristiano ronaldo/28.jpg
# faces/train/barack obama/24.jpg
# faces/train/natalie portman/54.jpg
# faces/train/justin timberlake/49.jpg
# faces/test/natalie portman/7.jpg
# faces/train/george clooney/16.jpg
# faces/train/cristiano ronaldo/45.jpg
# faces/train/emma watson/20.jpg
# faces/test/barack obama/13.jpg
# faces/train/barack obama/41.jpg
# faces/train/emma watson/39.jpg
# faces/train/tom cruise/14.jpg
# faces/train/george clooney/33.jpg
# faces/test/angelina jolie/1.jpg
# faces/test/tom cruise/2.jpg
# faces/train/johnny depp/22.jpg
# faces/train/tom cruise/31.jpg
# faces/train/scarlett johansson/14.jpg
# faces/test/george clooney/5.jpg
# faces/test/hillary clinton/3.jpg
# faces/train/george clooney/50.jpg
# faces/train/hillary clinton/
# faces/train/natalie portman/14.jpg
# faces/test/scarlett johansson/1.jpg
# faces/test/anne hathaway/8.jpg
# faces/train/scarlett johansson/31.jpg
# faces/train/nicole kidman/4.jpg
# faces/train/angelina jolie/12.jpg
# faces/train/leonardo dicaprio/38.jpg
# faces/train/scarlett johansson/7.jpg
# faces/train/hillary clinton/24.jpg
# faces/test/justin timberlake/15.jpg
# faces/train/brad pitt/27.jpg
# faces/test/cristiano ronaldo/11.jpg
# faces/train/anne hathaway/10.jpg
# faces/test/emma watson/4.jpg
# faces/train/anne hathaway/29.jpg
# faces/train/hillary clinton/41.jpg
# faces/train/brad pitt/44.jpg
# faces/train/jennifer aniston/45.jpg
# faces/train/cristiano ronaldo/17.jpg
# faces/test/hillary clinton/15.jpg
# faces/train/barack obama/13.jpg
# faces/train/natalie portman/43.jpg
# faces/train/justin timberlake/38.jpg
# faces/train/angelina jolie/4.jpg
# faces/train/anne hathaway/46.jpg
# faces/train/cristiano ronaldo/34.jpg
# faces/train/george clooney/8.jpg
# faces/train/emma watson/28.jpg
# faces/train/natalie portman/60.jpg
# faces/test/johnny depp/
# faces/train/justin timberlake/55.jpg
# faces/test/jennifer aniston/2.jpg
# faces/train/george clooney/22.jpg
# faces/train/barack obama/49.jpg
# faces/test/cristiano ronaldo/9.jpg
# faces/train/johnny depp/11.jpg
# faces/train/emma watson/45.jpg
# faces/test/leonardo dicaprio/8.jpg
# faces/test/angelina jolie/9.jpg
# faces/train/tom cruise/20.jpg
# faces/train/tom cruise/6.jpg
# faces/train/tom cruise/39.jpg
# faces/train/nicole kidman/26.jpg
# faces/train/scarlett johansson/20.jpg
# faces/train/cristiano ronaldo/7.jpg
# faces/train/anne hathaway/
# faces/test/scarlett johansson/9.jpg
# faces/train/scarlett johansson/39.jpg
# faces/train/natalie portman/20.jpg
# faces/train/leonardo dicaprio/27.jpg
# faces/train/leonardo dicaprio/6.jpg
# faces/test/johnny depp/13.jpg
# faces/train/hillary clinton/13.jpg
# faces/train/nicole kidman/43.jpg
# faces/train/brad pitt/16.jpg
# faces/train/jennifer aniston/17.jpg
# faces/test/scarlett johansson/
# faces/train/leonardo dicaprio/44.jpg
# faces/train/anne hathaway/18.jpg
# faces/train/hillary clinton/30.jpg
# faces/train/brad pitt/33.jpg
# faces/train/angelina jolie/37.jpg
# faces/train/jennifer aniston/34.jpg
# faces/train/nicole kidman/55.jpg
# faces/train/hillary clinton/49.jpg
# faces/train/natalie portman/32.jpg
# faces/train/justin timberlake/27.jpg
# faces/train/anne hathaway/35.jpg
# faces/train/jennifer aniston/51.jpg
# faces/train/angelina jolie/54.jpg
# faces/train/natalie portman/1.jpg
# faces/train/cristiano ronaldo/23.jpg
# faces/train/emma watson/17.jpg
# faces/train/justin timberlake/44.jpg
# faces/train/anne hathaway/52.jpg
# faces/test/natalie portman/2.jpg
# faces/test/george clooney/
# faces/train/george clooney/11.jpg
# faces/train/cristiano ronaldo/40.jpg
# faces/train/barack obama/38.jpg
# faces/train/barack obama/5.jpg
# faces/train/emma watson/34.jpg
# faces/train/brad pitt/6.jpg
# faces/train/justin timberlake/4.jpg
# faces/train/johnny depp/19.jpg
# faces/train/barack obama/55.jpg
# faces/test/leonardo dicaprio/10.jpg
# faces/train/tom cruise/28.jpg
# faces/train/george clooney/47.jpg
# faces/train/nicole kidman/15.jpg
# faces/train/johnny depp/36.jpg
# faces/train/leonardo dicaprio/16.jpg
# faces/train/scarlett johansson/28.jpg
# faces/test/anne hathaway/
# faces/train/tom cruise/45.jpg
# faces/train/nicole kidman/32.jpg
# faces/test/anne hathaway/3.jpg
# faces/train/natalie portman/28.jpg
# faces/train/scarlett johansson/45.jpg
# faces/train/johnny depp/53.jpg
# faces/train/leonardo dicaprio/33.jpg
# faces/train/scarlett johansson/2.jpg
# faces/train/brad pitt/22.jpg
# faces/train/angelina jolie/26.jpg
# faces/train/jennifer aniston/23.jpg
# faces/test/jennifer aniston/
# faces/train/leonardo dicaprio/50.jpg
# faces/test/nicole kidman/7.jpg
# faces/train/justin timberlake/16.jpg
# faces/train/anne hathaway/24.jpg
# faces/train/emma watson/7.jpg
# faces/train/jennifer aniston/40.jpg
# faces/train/angelina jolie/43.jpg
# faces/train/cristiano ronaldo/12.jpg
# faces/train/jennifer aniston/8.jpg
# faces/test/hillary clinton/10.jpg
# faces/train/hillary clinton/55.jpg
# faces/test/brad pitt/3.jpg
# faces/train/brad pitt/58.jpg
# faces/train/natalie portman/9.jpg
# faces/train/anne hathaway/41.jpg
# faces/train/angelina jolie/60.jpg
# faces/train/cristiano ronaldo/48.jpg
# faces/train/barack obama/27.jpg
# faces/train/emma watson/23.jpg
# faces/train/george clooney/3.jpg
# faces/test/natalie portman/
# faces/train/justin timberlake/50.jpg
# faces/train/george clooney/19.jpg
# faces/train/barack obama/44.jpg
# faces/test/cristiano ronaldo/4.jpg
# faces/train/tom cruise/17.jpg
# faces/test/leonardo dicaprio/3.jpg
# faces/train/george clooney/36.jpg
# faces/train/emma watson/40.jpg
# faces/test/angelina jolie/4.jpg
# faces/train/anne hathaway/3.jpg
# faces/train/johnny depp/25.jpg
# faces/train/scarlett johansson/17.jpg
# faces/train/tom cruise/34.jpg
# faces/test/hillary clinton/6.jpg
# faces/train/tom cruise/1.jpg
# faces/train/nicole kidman/21.jpg
# faces/test/brad pitt/15.jpg
# faces/train/cristiano ronaldo/2.jpg
# faces/train/natalie portman/17.jpg
# faces/train/scarlett johansson/34.jpg
# faces/train/johnny depp/42.jpg
# faces/train/leonardo dicaprio/22.jpg
# faces/train/leonardo dicaprio/1.jpg
# faces/train/tom cruise/51.jpg
# faces/test/nicole kidman/
# faces/train/nicole kidman/7.jpg
# faces/train/jennifer aniston/12.jpg
# faces/train/hillary clinton/27.jpg
# faces/train/anne hathaway/13.jpg
# faces/test/justin timberlake/8.jpg
# faces/test/emma watson/7.jpg
# faces/test/scarlett johansson/10.jpg
# faces/train/angelina jolie/32.jpg
# faces/train/hillary clinton/44.jpg
# faces/train/brad pitt/47.jpg
# faces/train/jennifer aniston/48.jpg
# faces/train/anne hathaway/30.jpg
# faces/train/barack obama/16.jpg
# faces/train/natalie portman/46.jpg
# faces/test/johnny depp/1.jpg
# faces/train/cristiano ronaldo/37.jpg
# faces/train/emma watson/12.jpg
# faces/train/barack obama/33.jpg
# faces/train/justin timberlake/58.jpg
# faces/test/hillary clinton/
# faces/train/george clooney/25.jpg
# faces/train/brad pitt/1.jpg
# faces/train/tom cruise/9.jpg
# faces/train/barack obama/50.jpg
# faces/train/emma watson/48.jpg
# faces/train/tom cruise/23.jpg
# faces/train/george clooney/42.jpg
# faces/train/nicole kidman/10.jpg
# faces/train/nicole kidman/29.jpg
# faces/train/johnny depp/31.jpg
# faces/train/leonardo dicaprio/11.jpg
# faces/train/scarlett johansson/23.jpg
# faces/train/tom cruise/40.jpg
# faces/test/barack obama/2.jpg
# faces/train/natalie portman/23.jpg
# faces/train/leonardo dicaprio/9.jpg
# faces/train/brad pitt/19.jpg
# faces/train/hillary clinton/16.jpg
# faces/train/nicole kidman/46.jpg
# faces/train/scarlett johansson/40.jpg
# faces/test/nicole kidman/15.jpg
# faces/train/angelina jolie/21.jpg
# faces/train/leonardo dicaprio/47.jpg
# faces/train/hillary clinton/33.jpg
# faces/train/brad pitt/36.jpg
# faces/test/natalie portman/14.jpg
# faces/test/nicole kidman/2.jpg
# faces/train/angelina jolie/57.jpg
# faces/train/justin timberlake/11.jpg
# faces/train/johnny depp/3.jpg
# faces/train/emma watson/2.jpg
# faces/train/jennifer aniston/3.jpg
# faces/train/anne hathaway/38.jpg
# faces/train/hillary clinton/50.jpg
# faces/train/brad pitt/53.jpg
# faces/train/natalie portman/4.jpg
# faces/train/jennifer aniston/54.jpg
# faces/train/cristiano ronaldo/26.jpg
# faces/test/johnny depp/9.jpg
# faces/train/barack obama/22.jpg
# faces/train/natalie portman/52.jpg
# faces/train/justin timberlake/47.jpg
# faces/train/anne hathaway/55.jpg
# faces/test/natalie portman/5.jpg
# faces/train/george clooney/14.jpg
# faces/train/cristiano ronaldo/43.jpg
# faces/test/barack obama/11.jpg
# faces/train/emma watson/37.jpg
# faces/train/tom cruise/12.jpg
# faces/train/brad pitt/9.jpg
# faces/train/justin timberlake/7.jpg
# faces/train/george clooney/31.jpg
# faces/train/barack obama/58.jpg
# faces/train/johnny depp/20.jpg
# faces/train/nicole kidman/18.jpg
# faces/train/scarlett johansson/12.jpg
# faces/test/george clooney/3.jpg
# faces/test/brad pitt/10.jpg
# /content/drive/My Drive/cse455/assignments/assignment4_colab/assignment4

# %% [markdown]
# # Assignment 4 Part 2
# In this homework, we will implement a simplified version of object detection process. Note that the tests on the notebook are not comprehensive, autograder will contain more tests.

# %%
from __future__ import print_function
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from skimage import io, color
from skimage.feature import hog
from skimage import data, color, exposure
from skimage.transform import rescale, resize, downscale_local_mean
import glob, os
import fnmatch
import time

import warnings
warnings.filterwarnings('ignore')

from detection import *
from visualization import *
from util import *

# This code is to make matplotlib figures appear inline in the
# notebook rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %% [markdown]
# # Part 1: Hog Representation (10 points)
#
# In this section, we will compute the average hog representation of human faces.<br>
# There are 31 aligned face images provided in the `\face` folder. They are all aligned and have the same size. We will get an average face from these images and compute a hog feature representation for the averaged face. <br>
# Use the hog function provided by skimage library, and implement a hog representation of objects.
# Implement **`hog_feature`** function in `detection.py`

# %%
image_paths = fnmatch.filter(os.listdir('./face'), '*.jpg')
list.sort(image_paths)
n = len(image_paths)
face_shape, avg_face = load_faces(image_paths, n)

(face_feature, hog_image) = hog_feature(avg_face)

print(np.sum(face_feature))
assert np.abs(np.sum(face_feature) - 499.970465079) < 1e-2

plot_part1(avg_face, hog_image)
# Out:
# 499.9704572768695

# %% [markdown]
# # Part 2: Sliding Window (30 points)
# Implement **`sliding_window`** function to have windows slide across an image with a specific window size. The window slides through the image and check if an object is detected with a high score at every location. These scores will generate a response map and you will be able to find the location of the window with the highest hog score.

# %%
image_path = 'image_0001.jpg'

image = color.rgb2gray(io.imread(image_path))
image = rescale(image, 0.8)

(hogFeature, hogImage) = hog_feature(image)

(winH, winW) = face_shape
(score, r, c, response_map) = sliding_window(image, face_feature, stepSize=30, windowSize=face_shape)
crop = image[r:r+winH, c:c+winW]

plot_part2(image, r, c, response_map, winW, winH)

# %% [markdown]
# Sliding window successfully found the human face in the above example. However, in the cell below, we are only changing the scale of the image, and you can see that sliding window does not work once the scale of the image is changed.

# %%
image_path = 'image_0001.jpg'
image = color.rgb2gray(io.imread(image_path))
image = rescale(image, 1.0)

(winH, winW) = face_shape
(score, r, c, max_response_map) = sliding_window(image, face_feature, stepSize=30, windowSize=face_shape)

crop = image[r:r+winH, c:c+winW]

plot_part2(image, r, c, max_response_map, winW, winH)

# %% [markdown]
# # Part 3: Image Pyramids (25 points)
# In order to make sliding window work for different scales of images, you need to implement image pyramids where you resize the image to different scales and run the sliding window method on each resized image. This way you scale the objects and can detect both small and large objects.

# %% [markdown]
# ###  3.1 Image Pyramid (10 points)
#
# Implement **`pyramid`** function in `detection.py`, this will create pyramid of images at different scales. Run the following code, and you will see the shape of the original image gets smaller until it reaches a minimum size.

# %%
image_path = 'image_0001.jpg'

image = color.rgb2gray(io.imread(image_path))
image = rescale(image, 1.2)

images = pyramid(image, scale = 0.9)

plot_part3_1(images)

# %% [markdown]
# ###  3.2 Pyramid Score (15 points)
#
# After getting the image pyramid, we will run sliding window on all the images to find a place that gets the highest score. Implement **`pyramid_score`** function in `detection.py`. It will return the highest score and its related information in the image pyramids.

# %%
image_path = 'image_0001.jpg'

image = color.rgb2gray(io.imread(image_path))
image = rescale(image, 1.2)

(winH, winW) = face_shape
max_score, maxr, maxc, max_scale, max_response_map = pyramid_score \
        (image, face_feature, face_shape, stepSize = 30, scale=0.8)

plot_part3_2(image, max_scale, winW, winH, maxc, maxr, max_response_map)

# %% [markdown]
# From the above example, we can see that image pyramid has fixed the problem of scaling. Then in the example below, we will try another image and implement a deformable parts model.

# %%
image_path = 'image_0338.jpg'
image = color.rgb2gray(io.imread(image_path))
image = rescale(image, 1.0)

(winH, winW) = face_shape

max_score, maxr, maxc, max_scale, max_response_map = pyramid_score \
    (image, face_feature, face_shape, stepSize = 30, scale=0.8)

plot_part3_2(image, max_scale, winW, winH, maxc, maxr, max_response_map)

# %% [markdown]
# # Part 4: Deformable Parts Detection
# In order to solve the problem above, you will implement deformable parts model in this section, and apply it on human faces. <br>
# The first step is to get a detector for each part of the face, including left eye, right eye, nose and mouth. <br>
# For example for the left eye, we have provided the groundtruth location of left eyes for each image in the `\face` directory. This is stored in the `lefteyes` array with shape `(n,2)`, each row is the `(r,c)` location of the center of left eye. You will then find the average hog representation of the left eyes in the images.

# %% [markdown]
# Run through the following code to get a detector for left eyes.

# %%
image_paths = fnmatch.filter(os.listdir('./face'), '*.jpg')

parts = read_facial_labels(image_paths)
lefteyes, righteyes, noses, mouths = parts

# Typical shape for left eye
lefteye_h = 10
lefteye_w = 20

lefteye_shape = (lefteye_h, lefteye_w)

avg_lefteye = get_detector(lefteye_h, lefteye_w, lefteyes, image_paths)
(lefteye_feature, lefteye_hog) = hog_feature(avg_lefteye, pixel_per_cell=2)

plot_part4(avg_lefteye, lefteye_hog, 'left eye')

# %% [markdown]
# Run through the following code to get a detector for right eye.

# %%
righteye_h = 10
righteye_w = 20

righteye_shape = (righteye_h, righteye_w)

avg_righteye = get_detector(righteye_h, righteye_w, righteyes, image_paths)

(righteye_feature, righteye_hog) = hog_feature(avg_righteye, pixel_per_cell=2)

plot_part4(avg_righteye, righteye_hog, 'right eye')

# %% [markdown]
# Run through the following code to get a detector for nose.

# %%
nose_h = 30
nose_w = 26

nose_shape = (nose_h, nose_w)

avg_nose = get_detector(nose_h, nose_w, noses, image_paths)

(nose_feature, nose_hog) = hog_feature(avg_nose, pixel_per_cell=2)

plot_part4(avg_nose, nose_hog, 'nose')

# %% [markdown]
# Run through the following code to get a detector for mouth

# %%
mouth_h = 20
mouth_w = 36

mouth_shape = (mouth_h, mouth_w)

avg_mouth = get_detector(mouth_h, mouth_w, mouths, image_paths)

(mouth_feature, mouth_hog) = hog_feature(avg_mouth, pixel_per_cell=2)

detectors_list = [lefteye_feature, righteye_feature, nose_feature, mouth_feature]

plot_part4(avg_mouth, mouth_hog, 'mouth')

# %% [markdown]
# # Part 5: Human Parts Location (15points)
#
# ###  5.1 Compute displacement (10 points)
#
# Implement **`compute_displacement`** to get an average shift vector mu and standard deviation sigma for each part of the face. The vector mu is the distance from the main center, i.e the center of the face, to the center of the part. <br>

# %%
# test for compute_displacement
test_array = np.array([[0,1],[1,2],[2,3],[3,4]])
test_shape = (6,6)
mu, std = compute_displacement(test_array, test_shape)
assert(np.all(mu == [1,0]))
assert(np.sum(std-[ 1.11803399,  1.11803399])<1e-5)
print("Your implementation is correct!")
# Out:
# Your implementation is correct!

# %%
lefteye_mu, lefteye_std = compute_displacement(lefteyes, face_shape)
righteye_mu, righteye_std = compute_displacement(righteyes, face_shape)
nose_mu, nose_std = compute_displacement(noses, face_shape)
mouth_mu, mouth_std = compute_displacement(mouths, face_shape)

# %% [markdown]
# After getting the shift vectors, we can run our detector on a test image. We will first run the following code to detect each part of left eye, right eye, nose and mouth in  the image. You will see a response map for each of them.

# %%
image_path = 'image_0338.jpg'
image = color.rgb2gray(io.imread(image_path))
image = rescale(image, 1.0)

(face_H, face_W) = face_shape
max_score, face_r, face_c, face_scale, face_response_map = pyramid_score\
    (image, face_feature, face_shape,stepSize = 30, scale=0.8)

plot_part5_1(face_response_map)

# %%
max_score, lefteye_r, lefteye_c, lefteye_scale, lefteye_response_map = \
    pyramid_score(image, lefteye_feature,lefteye_shape, stepSize = 20,scale=0.9, pixel_per_cell = 2)

lefteye_response_map = resize(lefteye_response_map, face_response_map.shape)

plot_part5_1(lefteye_response_map)

# %%
max_score, righteye_r, righteye_c, righteye_scale, righteye_response_map = \
    pyramid_score (image, righteye_feature, righteye_shape, stepSize = 20,scale=0.9, pixel_per_cell=2)

righteye_response_map = resize(righteye_response_map, face_response_map.shape)

plot_part5_1(righteye_response_map)

# %%
max_score, nose_r, nose_c, nose_scale, nose_response_map = \
    pyramid_score (image, nose_feature, nose_shape, stepSize = 20,scale=0.9, pixel_per_cell = 2)

nose_response_map = resize(nose_response_map, face_response_map.shape)

plot_part5_1(nose_response_map)

# %%
max_score, mouth_r, mouth_c, mouth_scale, mouth_response_map =\
    pyramid_score (image, mouth_feature, mouth_shape, stepSize = 20,scale=0.9, pixel_per_cell = 2)

mouth_response_map = resize(mouth_response_map, face_response_map.shape)

plot_part5_1(mouth_response_map)

# %% [markdown]
# ###  5.2 Shift heatmap (5 points)
#
# After getting the response maps for each part of the face, we will shift these maps so that they all have the same center as the face. We have calculated the shift vector mu in `compute_displacement`, so we are shifting based on vector mu. Implement `shift_heatmap` function in `detection.py`.

# %%
face_heatmap_shifted = shift_heatmap(face_response_map, [0,0])

lefteye_heatmap_shifted = shift_heatmap(lefteye_response_map, lefteye_mu)
righteye_heatmap_shifted = shift_heatmap(righteye_response_map, righteye_mu)
nose_heatmap_shifted = shift_heatmap(nose_response_map, nose_mu)
mouth_heatmap_shifted = shift_heatmap(mouth_response_map, mouth_mu)

plot_part5_2(lefteye_heatmap_shifted, righteye_heatmap_shifted,
                 nose_heatmap_shifted, mouth_heatmap_shifted)

# %% [markdown]
# # Part 6: Gaussian Filter (20 points)
#
# ## Part 6.1 Gaussian Filter
# In this part, apply gaussian filter convolution to each heatmap. Blur by kernel of standard deviation sigma, and then add the heatmaps of the parts with the heatmap of the face. On the combined heatmap, find the maximum value and its location. You can use function provided by skimage to implement **`gaussian_heatmap`**.

# %%
heatmap_face= face_heatmap_shifted

heatmaps = [lefteye_heatmap_shifted,
           righteye_heatmap_shifted,
           nose_heatmap_shifted,
           mouth_heatmap_shifted]
sigmas = [lefteye_std, righteye_std, nose_std, mouth_std]

heatmap, i , j = gaussian_heatmap(heatmap_face, heatmaps, sigmas)
print(heatmap.shape, image.shape)
plot_part6_1(winH, winW, heatmap, image, i, j)
# Out:
# (220, 333) (344, 520)

# %% [markdown]
# ## 6.2 Result Analysis (10 points)
#
# Does your DPM work on detecting human faces? Can you think of a case where DPM may work better than the detector we had in part 3 (sliding window + image pyramid)? You can also have examples that are not faces.

# %% [markdown]
# **Your Answer:** Write your answer in this markdown cell.
#
# Yes, my DPM works on detecting human faces. Generally speaking, two fairly obvious cases where DPM may work better than the detector we had in part 3 are:
# 1. The object we are trying to find is partly obscured (i.e. overlapping faces).
# 2. The object has movable parts or can change shape (i.e. eyebrow).

# %% [markdown]
# ## Extra Credit (1 point)
# You have tried detecting one face from the image, and the next step is to extend it to detecting multiple occurences of the object. For example in the following image, how do you detect more than one face from your response map? Implement the function **`detect_multiple`**, and write code to visualize your detected faces in the cell below.

# %%
image_path = 'image_0002.jpg'
image = color.rgb2gray(io.imread(image_path))
plt.imshow(image)
plt.show()

# %%
image_path = 'image_0002.jpg'
image = color.rgb2gray(io.imread(image_path))
heatmap = get_heatmap (image,face_feature, face_shape,detectors_list, parts )

plt.imshow(heatmap, cmap='viridis', interpolation='nearest')
plt.show()

# %%
detected_faces = detect_multiple(image, heatmap)

# Visualize your detected faces

### YOUR CODE HERE
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

pass

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
### END YOUR CODE
